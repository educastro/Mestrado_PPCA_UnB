# %%
import mysql.connector as msql
from mysql.connector import Error
import pandas as pd

# %%
alunos = pd.read_csv("..\Dados\SUP_ALUNO_2019_DF.csv", sep=";", encoding='ISO-8859-1')
ies = pd.read_csv("..\Dados\SUP_IES_2019_DF.csv", sep=";", encoding='ISO-8859-1')
docentes = pd.read_csv("..\Dados\BD_DOCENTES.csv", sep=";", encoding='ISO-8859-1')
cursos = pd.read_csv("..\Dados\SUP_CURSO_2019_DF.csv", sep=";", encoding='ISO-8859-1')

# %%
try:
    conn = msql.connect(host='localhost', database='mydb', user='root', password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
#         cursor.execute('DROP TABLE IF EXISTS docente;')
#         print('Creating table....')
        # in the below line please pass the create table statement which you want #to create
        #cursor.execute("CREATE TABLE docente(iddocente INT NOT NULL AUTO_INCREMENT,ID_DOCENTE VARCHAR(32) NOT NULL,TP_SITUACAO INT(1) NOT NULL,TP_ESCOLARIDADE INT(1) NULL,TP_REGIME_TRABALHO INT(1) NULL,TP_SEXO INT(1) NULL,NU_ANO_NASCIMENTO INT(4) NULL,NU_MES_NASCIMENTO INT(2) NULL,NU_DIA_NASCIMENTO INT(2) NULL,NU_IDADE INT(3) NULL,TP_COR_RACA INT(1) NULL,CO_PAIS_ORIGEM INT(8) NULL,TP_NACIONALIDADE INT(1) NULL, PRIMARY KEY (iddocente))")
        #cursor.execute("CREATE TABLE aluno(CO_IES varchar(255),TP_CATEGORIA_ADMINISTRATIVA varchar(255),TP_ORGANIZACAO_ACADEMICA varchar(255),CO_CURSO varchar(255),TP_TURNO varchar(255),TP_GRAU_ACADEMICO varchar(255),TP_MODALIDADE_ENSINO varchar(255),TP_NIVEL_ACADEMICO varchar(255),ID_ALUNO varchar(255),CO_ALUNO_CURSO varchar(255),TP_COR_RACA varchar(255),TP_SEXO varchar(255),NU_ANO_NASCIMENTO varchar(255),NU_MES_NASCIMENTO varchar(255),NU_DIA_NASCIMENTO varchar(255),CO_PAIS_ORIGEM varchar(255),IN_DEFICIENCIA varchar(255),TP_SITUACAO varchar(255),QT_CARGA_HORARIA_TOTAL varchar(255),QT_CARGA_HORARIA_INTEG varchar(255),DT_INGRESSO_CURSO varchar(255),IN_FINANCIAMENTO_ESTUDANTIL varchar(255),IN_APOIO_SOCIAL varchar(255),IN_APOIO_ALIMENTACAO varchar(255),IN_APOIO_BOLSA_PERMANENCIA varchar(255),IN_APOIO_BOLSA_TRABALHO varchar(255),IN_APOIO_MATERIAL_DIDATICO varchar(255),IN_APOIO_MORADIA varchar(255),IN_APOIO_TRANSPORTE varchar(255),IN_ATIVIDADE_EXTRACURRICULAR varchar(255),IN_COMPLEMENTAR_ESTAGIO varchar(255),IN_COMPLEMENTAR_EXTENSAO varchar(255),IN_COMPLEMENTAR_MONITORIA varchar(255),IN_COMPLEMENTAR_PESQUISA varchar(255),IN_BOLSA_ESTAGIO varchar(255),IN_BOLSA_EXTENSAO varchar(255),IN_BOLSA_MONITORIA varchar(255),IN_BOLSA_PESQUISA varchar(255),TP_ESCOLA_CONCLUSAO_ENS_MEDIO varchar(255),IN_ALUNO_PARFOR varchar(255),TP_SEMESTRE_CONCLUSAO varchar(255),TP_SEMESTRE_REFERENCIA varchar(255),IN_MOBILIDADE_ACADEMICA varchar(255),TP_MOBILIDADE_ACADEMICA varchar(255),TP_MOBILIDADE_ACADEMICA_INTERN varchar(255),CO_IES_DESTINO varchar(255),CO_PAIS_DESTINO varchar(255),IN_MATRICULA varchar(255),IN_CONCLUINTE varchar(255),IN_INGRESSO_TOTAL varchar(255),NU_ANO_INGRESSO varchar(255))")
#         print("Table is created....")
        #loop through the data frame
        for i,row in docentes.iterrows():
            #here %S means string values 
            #sql = "INSERT INTO docente VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            #cursor.execute(sql, tuple(row))
            cursor.execute("""INSERT INTO docente (ID_DOCENTE, TP_SITUACAO, TP_ESCOLARIDADE, TP_REGIME_TRABALHO, TP_SEXO, NU_ANO_NASCIMENTO, NU_MES_NASCIMENTO, NU_DIA_NASCIMENTO, NU_IDADE, TP_COR_RACA, CO_PAIS_ORIGEM, TP_NACIONALIDADE) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""", (row["ID_DOCENTE"], row["TP_SITUACAO"], row["TP_ESCOLARIDADE"], row["TP_REGIME_TRABALHO"], row["TP_SEXO"], row["NU_ANO_NASCIMENTO"], row["NU_MES_NASCIMENTO"], row["NU_DIA_NASCIMENTO"], row["NU_IDADE"], row["TP_COR_RACA"], row["CO_PAIS_ORIGEM"], row["TP_NACIONALIDADE"]))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('mydb',)
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
try:
    conn = msql.connect(host='localhost', database='inep_df', user='root', password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)
        cursor.execute('DROP TABLE IF EXISTS ies;')
        print('Creating table....')
# in the below line please pass the create table statement which you want #to create
        cursor.execute("CREATE TABLE aluno(CO_IES varchar(255),TP_CATEGORIA_ADMINISTRATIVA varchar(255),TP_ORGANIZACAO_ACADEMICA varchar(255),CO_CURSO varchar(255),TP_TURNO varchar(255),TP_GRAU_ACADEMICO varchar(255),TP_MODALIDADE_ENSINO varchar(255),TP_NIVEL_ACADEMICO varchar(255),ID_ALUNO varchar(255),CO_ALUNO_CURSO varchar(255),TP_COR_RACA varchar(255),TP_SEXO varchar(255),NU_ANO_NASCIMENTO varchar(255),NU_MES_NASCIMENTO varchar(255),NU_DIA_NASCIMENTO varchar(255),CO_PAIS_ORIGEM varchar(255),IN_DEFICIENCIA varchar(255),TP_SITUACAO varchar(255),QT_CARGA_HORARIA_TOTAL varchar(255),QT_CARGA_HORARIA_INTEG varchar(255),DT_INGRESSO_CURSO varchar(255),IN_FINANCIAMENTO_ESTUDANTIL varchar(255),IN_APOIO_SOCIAL varchar(255),IN_APOIO_ALIMENTACAO varchar(255),IN_APOIO_BOLSA_PERMANENCIA varchar(255),IN_APOIO_BOLSA_TRABALHO varchar(255),IN_APOIO_MATERIAL_DIDATICO varchar(255),IN_APOIO_MORADIA varchar(255),IN_APOIO_TRANSPORTE varchar(255),IN_ATIVIDADE_EXTRACURRICULAR varchar(255),IN_COMPLEMENTAR_ESTAGIO varchar(255),IN_COMPLEMENTAR_EXTENSAO varchar(255),IN_COMPLEMENTAR_MONITORIA varchar(255),IN_COMPLEMENTAR_PESQUISA varchar(255),IN_BOLSA_ESTAGIO varchar(255),IN_BOLSA_EXTENSAO varchar(255),IN_BOLSA_MONITORIA varchar(255),IN_BOLSA_PESQUISA varchar(255),TP_ESCOLA_CONCLUSAO_ENS_MEDIO varchar(255),IN_ALUNO_PARFOR varchar(255),TP_SEMESTRE_CONCLUSAO varchar(255),TP_SEMESTRE_REFERENCIA varchar(255),IN_MOBILIDADE_ACADEMICA varchar(255),TP_MOBILIDADE_ACADEMICA varchar(255),TP_MOBILIDADE_ACADEMICA_INTERN varchar(255),CO_IES_DESTINO varchar(255),CO_PAIS_DESTINO varchar(255),IN_MATRICULA varchar(255),IN_CONCLUINTE varchar(255),IN_INGRESSO_TOTAL varchar(255),NU_ANO_INGRESSO varchar(255))")
        print("Table is created....")
        #loop through the data frame
        for i,row in alunos.iterrows():
            #here %S means string values 
            sql = "INSERT INTO inep_df.aluno VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)

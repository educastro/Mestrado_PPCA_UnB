# %%
import mysql.connector as msql
from mysql.connector import Error
import pandas as pd

# %%
alunos = pd.read_csv("..\Dados\SUP_ALUNO_2019_DF.csv", sep=";", encoding='ISO-8859-1')
ies = pd.read_csv("..\Dados\SUP_IES_2019_DF.csv", sep=";", encoding='ISO-8859-1')
docentes = pd.read_csv("..\Dados\SUP_DOCENTE_2019_DF.csv", sep=";", encoding='ISO-8859-1')
cursos = pd.read_csv("..\Dados\SUP_CURSO_2019_DF.csv", sep=";", encoding='ISO-8859-1')

# %%
#### INSERÇÃO DE IES ####
try:
    conn = msql.connect(host='localhost', database='mydb', user='root', password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

        #loop through the data frame
        for i,row in ies.iterrows():
            #here %S means string values 
            cursor.execute("""INSERT INTO instituicao_ensino_superior (CO_IES, TP_CATEGORIA_ADMINISTRATIVA, TP_ORGANIZACAO_ACADEMICA, CO_UF, NO_IES, SG_IES) VALUES (%s, %s, %s, %s, %s, %s)""", (row["CO_IES"], row["TP_CATEGORIA_ADMINISTRATIVA"], row["TP_ORGANIZACAO_ACADEMICA"], row["CO_UF"], row["NO_IES"], row["SG_IES"]))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('mydb',)
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
try:
    conn = msql.connect(host='localhost', database='mydb', user='root', password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

        #loop through the data frame
        for i,row in docentes.iterrows():
            #here %S means string values 
            cursor.execute("""INSERT INTO docente (ID_DOCENTE, TP_SITUACAO, TP_ESCOLARIDADE, TP_REGIME_TRABALHO, TP_SEXO, NU_ANO_NASCIMENTO, NU_MES_NASCIMENTO, NU_DIA_NASCIMENTO, NU_IDADE, TP_COR_RACA, CO_PAIS_ORIGEM, TP_NACIONALIDADE) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""", (row["ID_DOCENTE"], row["TP_SITUACAO"], row["TP_ESCOLARIDADE"], row["TP_REGIME_TRABALHO"], row["TP_SEXO"], row["NU_ANO_NASCIMENTO"], row["NU_MES_NASCIMENTO"], row["NU_DIA_NASCIMENTO"], row["NU_IDADE"], row["TP_COR_RACA"], row["CO_PAIS_ORIGEM"], row["TP_NACIONALIDADE"]))
            primary_key = cursor.lastrowid
            cursor.execute("""INSERT INTO docente_has_instituicao_ensino_superior (docente_iddocente, instituicao_ensino_superior_CO_IES) VALUES (%s, %s)""", (primary_key, row["CO_IES"]))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('mydb',)
# 57086
# Record inserted
# 57087
# Record inserted
# 57088
# Record inserted
# 57089
# Record inserted
# 57090
# Record inserted
# 57091
# Record inserted
# 57092
# Record inserted
# 57093
# Record inserted
# 57094
# Record inserted
# 57095
# Record inserted
# 57096
# Record inserted
# 57097
# Record inserted
# 57098
# Record inserted
# 57099
# Record inserted
# 57100
# Record inserted
# 57101
# Record inserted
# 57102
# Record inserted
# 57103
# Record inserted
# 57104
# Record inserted
# 57105
# Record inserted
# 57106
# Record inserted
# 57107
# Record inserted
# 57108
# Record inserted
# 57109
# Record inserted
# 57110
# Record inserted
# 57111
# Record inserted
# 57112
# Record inserted
# 57113
# Record inserted
# 57114
# Record inserted
# 57115
# Record inserted
# 57116
# Record inserted
# 57117
# Record inserted
# 57118
# Record inserted
# 57119
# Record inserted
# 57120
# Record inserted
# 57121
# Record inserted
# 57122
# ...

# %%
try:
    conn = msql.connect(host='localhost', database='mydb', user='root', password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

        #loop through the data frame
        for i,row in cursos.iterrows():
            #here %S means string values 
            cursor.execute("""INSERT INTO curso (CO_CURSO, NO_CURSO, CO_LOCAL_OFERTA, CO_UF, IN_CAPITAL, TP_SITUACAO, TP_GRAU_ACADEMICO, instituicao_ensino_superior_CO_IES) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)""", (row["CO_CURSO"], row["NO_CURSO"], row["CO_LOCAL_OFERTA"], row["CO_UF"], row["IN_CAPITAL"], row["TP_SITUACAO"], row["TP_GRAU_ACADEMICO"], row["CO_IES"]))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('mydb',)
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...

# %%
try:
    conn = msql.connect(host='localhost', database='mydb', user='root', password='root')
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

        #loop through the data frame
        for i,row in alunos.iterrows():
            #here %S means string values 
            cursor.execute("""INSERT INTO aluno (ID_ALUNO, CO_ALUNO_CURSO, TP_COR_RACA, TP_SEXO, NU_ANO_NASCIMENTO, NU_MES_NASCIMENTO, NU_DIA_NASCIMENTO, IN_DEFICIENCIA, IN_CONCLUINTE, TP_ESCOLA_CONCLUSAO_ENS_MEDIO, NU_ANO_INGRESSO, TP_NACIONALIDADE, CO_UF_NASCIMENTO, NU_IDADE, TP_SITUACAO, IN_INGRESSO_VESTIBULAR, IN_INGRESSO_ENEM, IN_INGRESSO_AVALIACAO_SERIADA, IN_APOIO_SOCIAL, TP_SEMESTRE_CONCLUSAO, TP_SEMESTRE_REFERENCIA, IN_MATRICULA) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)""", (row["ID_ALUNO"], row["CO_ALUNO_CURSO"], row["TP_COR_RACA"], row["TP_SEXO"], row["NU_ANO_NASCIMENTO"], row["NU_MES_NASCIMENTO"], row["NU_DIA_NASCIMENTO"], row["IN_DEFICIENCIA"], row["IN_CONCLUINTE"], row["TP_ESCOLA_CONCLUSAO_ENS_MEDIO"], row["NU_ANO_INGRESSO"], row["TP_NACIONALIDADE"], row["CO_UF_NASCIMENTO"], row["NU_IDADE"], row["TP_SITUACAO"], row["IN_INGRESSO_VESTIBULAR"], row["IN_INGRESSO_ENEM"], row["IN_INGRESSO_AVALIACAO_SERIADA"], row["IN_APOIO_SOCIAL"], row["TP_SEMESTRE_CONCLUSAO"], row["TP_SEMESTRE_REFERENCIA"], row["IN_MATRICULA"]))
            primary_key = cursor.lastrowid
            cursor.execute("""INSERT INTO aluno_has_curso (aluno_idaluno, curso_CO_CURSO, curso_instituicao_ensino_superior_CO_IES) VALUES (%s, %s, %s)""", (primary_key, row["CO_CURSO"], row["CO_IES"]))
            print("Record inserted")
            # the connection is not auto committed by default, so we must commit to save our changes
            conn.commit()
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('mydb',)
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# Record inserted
# ...
